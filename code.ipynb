# %%
import zipfile
import os

zip_file_path = 'movie_data.zip'
extract_folder = 'movie_data_extracted'

os.makedirs(extract_folder, exist_ok=True)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

extracted_files = os.listdir(extract_folder)
csv_files = [file for file in extracted_files if file.endswith('.csv')]

num_csv_files = len(csv_files)
print(f'There are {num_csv_files} CSV files in the dataset.')
# Out:
# There are 4 CSV files in the dataset.

# %%
import pandas as pd

movies_csv_path = os.path.join(extract_folder, 'movies.csv')

movies_df = pd.read_csv(movies_csv_path)

movies_shape = movies_df.shape
movies_shape
# Out:
# (9742, 3)

# %%
ratings_csv_path = os.path.join(extract_folder, 'ratings.csv')

ratings_df = pd.read_csv(ratings_csv_path)

ratings_shape = ratings_df.shape
ratings_shape
# Out:
# (100836, 4)

# %%
ratings_csv_path = r'C:\Users\hp\Downloads\Hackathon\movie_data_extracted\ratings.csv'

ratings_df = pd.read_csv(ratings_csv_path)

unique_user_ids = ratings_df['userId'].nunique()
print(unique_user_ids)
# Out:
# 610

# %%
movies_csv_path = r'C:\Users\hp\Downloads\Hackathon\movie_data_extracted\movies.csv'
movies_df = pd.read_csv(movies_csv_path)

ratings_count = ratings_df['movieId'].value_counts().reset_index()
ratings_count.columns = ['movieId', 'rating_count']

movies_ratings = pd.merge(ratings_count, movies_df, on='movieId')

max_rated_movie = movies_ratings.loc[movies_ratings['rating_count'].idxmax()]

print(f"The movie with the maximum number of ratings is '{max_rated_movie['title']}' with {max_rated_movie['rating_count']} ratings.")
# Out:
# The movie with the maximum number of ratings is 'Forrest Gump (1994)' with 329 ratings.

# %%
tags_csv_path = r'C:\Users\hp\Downloads\Hackathon\movie_data_extracted\tags.csv'

tags_df = pd.read_csv(tags_csv_path)

matrix_movie_id = movies_df[movies_df['title'] == 'Matrix, The (1999)']['movieId'].values[0]

matrix_tags = tags_df[tags_df['movieId'] == matrix_movie_id]['tag'].unique()

print("The tags submitted by users for 'Matrix, The (1999)' are:")
for tag in matrix_tags:
    print(tag)
# Out:
# The tags submitted by users for 'Matrix, The (1999)' are:
# martial arts
# sci-fi
# alternate universe
# philosophy
# post apocalyptic

# %%
movie_id = movies_df[movies_df['title'] == 'Terminator 2: Judgment Day (1991)']['movieId'].values[0]

terminator_ratings = ratings_df[ratings_df['movieId'] == movie_id]['rating']
average_rating = terminator_ratings.mean()

average_rating
# Out:
# 3.970982142857143

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(count=('rating', 'count'), mean_rating=('rating', 'mean')).reset_index()

merged_df = pd.merge(movies_df, grouped_ratings, on='movieId', how='inner')

filtered_movies_df = merged_df[merged_df['count'] > 50]

filtered_movies_df.head()
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
# 5        6              Heat (1995)
# 6        7           Sabrina (1995)
#
#                                         genres  count  mean_rating
# 0  Adventure|Animation|Children|Comedy|Fantasy    215     3.920930
# 1                   Adventure|Children|Fantasy    110     3.431818
# 2                               Comedy|Romance     52     3.259615
# 5                        Action|Crime|Thriller    102     3.946078
# 6                               Comedy|Romance     54     3.185185

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(count=('rating', 'count'), mean_rating=('rating', 'mean')).reset_index()
merged_df = pd.merge(movies_df, grouped_ratings, on='movieId', how='inner')

filtered_movies_df = merged_df[merged_df['count'] > 50]

top_movie = filtered_movies_df.loc[filtered_movies_df['mean_rating'].idxmax()]

print(f"The most popular movie based on average user ratings is: {top_movie['title']}")
# Out:
# The most popular movie based on average user ratings is: Shawshank Redemption, The (1994)

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(count=('rating', 'count')).reset_index()

merged_df = pd.merge(movies_df, grouped_ratings, on='movieId', how='inner')

filtered_movies_df = merged_df[merged_df['count'] > 50]

sorted_movies = filtered_movies_df.sort_values(by='count', ascending=False)

top_5_movies = sorted_movies.head(5)['title'].tolist()

print("Top 5 movies based on number of user ratings:", top_5_movies)

options = ["Pulp Fiction (1994)", "Bad Boys (1995)", "Silence of the Lambs, The (1991)", "Matrix, The (1999)"]
selected_options = [option for option in options if option in top_5_movies]
print("Selected options in top 5:", selected_options)
# Out:
# Top 5 movies based on number of user ratings: ['Forrest Gump (1994)', 'Shawshank Redemption, The (1994)', 'Pulp Fiction (1994)', 'Silence of the Lambs, The (1991)', 'Matrix, The (1999)']
# Selected options in top 5: ['Pulp Fiction (1994)', 'Silence of the Lambs, The (1991)', 'Matrix, The (1999)']

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(count=('rating', 'count')).reset_index()

merged_df = pd.merge(movies_df, grouped_ratings, on='movieId', how='inner')

filtered_movies_df = merged_df[merged_df['count'] > 50]

sci_fi_movies_df = filtered_movies_df[filtered_movies_df['genres'].str.contains('Sci-Fi')]

sorted_sci_fi_movies = sci_fi_movies_df.sort_values(by='count', ascending=False)

if len(sorted_sci_fi_movies) >= 3:
    third_most_popular_sci_fi_movie = sorted_sci_fi_movies.iloc[2]['title']
    print(f"The third most popular Sci-Fi movie based on the number of user ratings is: {third_most_popular_sci_fi_movie}")
else:
    print("There are not enough Sci-Fi movies with more than 50 ratings.")
# Out:
# The third most popular Sci-Fi movie based on the number of user ratings is: Jurassic Park (1993)

# %%
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'count'),
    average_rating=('rating', 'mean')
).reset_index()

merged_df = pd.merge(movies_df, grouped_ratings, on='movieId', how='inner')

filtered_df = merged_df[merged_df['rating_count'] > 50]

filtered_df.head(10)
# Out:
#     movieId                                  title  \
# 0         1                       Toy Story (1995)
# 1         2                         Jumanji (1995)
# 2         3                Grumpier Old Men (1995)
# 5         6                            Heat (1995)
# 6         7                         Sabrina (1995)
# 9        10                       GoldenEye (1995)
# 10       11         American President, The (1995)
# 15       16                          Casino (1995)
# 16       17           Sense and Sensibility (1995)
# 18       19  Ace Ventura: When Nature Calls (1995)
#
#                                          genres  rating_count  average_rating
# 0   Adventure|Animation|Children|Comedy|Fantasy           215        3.920930
# 1                    Adventure|Children|Fantasy           110        3.431818
# 2                                Comedy|Romance            52        3.259615
# 5                         Action|Crime|Thriller           102        3.946078
# 6                                Comedy|Romance            54        3.185185
# 9                     Action|Adventure|Thriller           132        3.496212
# 10                         Comedy|Drama|Romance            70        3.671429
# 15                                  Crime|Drama            82        3.926829
# 16                                Drama|Romance            67        3.776119
# 18                                       Comedy            88        2.727273

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    print(f"Accessing URL: {URL}")  # Debug print
    
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    
    response = requests.get(URL, headers=request_header)
    print(f"Response status code: {response.status_code}")  # Debug print
    
    soup = BeautifulSoup(response.text, 'html.parser')
    imdb_rating = soup.find('span', attrs={'class': 'sc-eb51e184-1 ljxVSS'})
    
    if imdb_rating:
        print(f"Found rating: {imdb_rating.text}")  
    else:
        print("Rating not found")
    
    return imdb_rating.text if imdb_rating else np.nan

links_df = pd.read_csv('movie_data_extracted\links.csv') 

merged_df = pd.merge(filtered_df, links_df, on='movieId')


movie_imdb_ratings = {}

for index, row in merged_df.iterrows():
    imdb_id = row['imdbId']
    title = row['title']
    rating = scrapper(imdb_id)
    movie_imdb_ratings[title] = rating

ratings_df = pd.DataFrame(list(movie_imdb_ratings.items()), columns=['Title', 'IMDb Rating'])


ratings_df.to_csv('movie_imdb_ratings.csv', index=False)

print("IMDb ratings have been saved to 'movie_imdb_ratings.csv'.")
# Out:
# Accessing URL: https://www.imdb.com/title/tt0114709/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0113497/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0113228/
# Response status code: 200
# Found rating: 6.7
# Accessing URL: https://www.imdb.com/title/tt0113277/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0114319/
# Response status code: 200
# Found rating: 6.3
# Accessing URL: https://www.imdb.com/title/tt0113189/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0112346/
# Response status code: 200
# Found rating: 6.8
# Accessing URL: https://www.imdb.com/title/tt0112641/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0114388/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0112281/
# Response status code: 200
# Found rating: 6.4
# Accessing URL: https://www.imdb.com/title/tt0113161/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0113627/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0114746/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0112431/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0112818/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0112697/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0114369/
# Response status code: 200
# Found rating: 8.6
# Accessing URL: https://www.imdb.com/title/tt0114148/
# Response status code: 200
# Found rating: 6.7
# Accessing URL: https://www.imdb.com/title/tt0114814/
# Response status code: 200
# Found rating: 8.5
# Accessing URL: https://www.imdb.com/title/tt0113862/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0116367/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0115759/
# Response status code: 200
# Found rating: 6.1
# Accessing URL: https://www.imdb.com/title/tt0116483/
# Response status code: 200
# Found rating: 7.0
# Accessing URL: https://www.imdb.com/title/tt0112573/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0075314/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0115685/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0112442/
# Response status code: 200
# Found rating: 6.8
# Accessing URL: https://www.imdb.com/title/tt0112384/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0112462/
# Response status code: 200
# Found rating: 5.4
# Accessing URL: https://www.imdb.com/title/tt0112642/
# Response status code: 200
# Found rating: 6.2
# Accessing URL: https://www.imdb.com/title/tt0112715/
# Response status code: 200
# Found rating: 5.3
# Accessing URL: https://www.imdb.com/title/tt0112740/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0112851/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0112864/
# Response status code: 200
# Found rating: 7.6
# Accessing URL: https://www.imdb.com/title/tt0113071/
# Response status code: 200
# Found rating: 6.0
# Accessing URL: https://www.imdb.com/title/tt0113481/
# Response status code: 200
# Found rating: 5.6
# Accessing URL: https://www.imdb.com/title/tt0113492/
# Response status code: 200
# Found rating: 5.6
# Accessing URL: https://www.imdb.com/title/tt0113957/
# Response status code: 200
# Found rating: 6.0
# Accessing URL: https://www.imdb.com/title/tt0114898/
# Response status code: 200
# Found rating: 6.3
# Accessing URL: https://www.imdb.com/title/tt0109445/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0109635/
# Response status code: 200
# Found rating: 6.2
# Accessing URL: https://www.imdb.com/title/tt0109686/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0109707/
# Response status code: 200
# Found rating: 7.8
# Accessing URL: https://www.imdb.com/title/tt0110148/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0076759/
# Response status code: 200
# Found rating: 8.6
# Accessing URL: https://www.imdb.com/title/tt0110322/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0110632/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0114069/
# Response status code: 200
# Found rating: 6.6
# Accessing URL: https://www.imdb.com/title/tt0110413/
# Response status code: 200
# Found rating: 8.5
# Accessing URL: https://www.imdb.com/title/tt0110912/
# Response status code: 200
# Found rating: 8.9
# Accessing URL: https://www.imdb.com/title/tt0110932/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0111282/
# Response status code: 200
# Found rating: 7.0
# Accessing URL: https://www.imdb.com/title/tt0111070/
# Response status code: 200
# Found rating: 6.6
# Accessing URL: https://www.imdb.com/title/tt0111161/
# Response status code: 200
# Found rating: 9.3
# Accessing URL: https://www.imdb.com/title/tt0111280/
# Response status code: 200
# Found rating: 6.6
# Accessing URL: https://www.imdb.com/title/tt0108550/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0114924/
# Response status code: 200
# Found rating: 6.8
# Accessing URL: https://www.imdb.com/title/tt0109040/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0109444/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0109446/
# Response status code: 200
# Found rating: 6.7
# Accessing URL: https://www.imdb.com/title/tt0109506/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0109830/
# Response status code: 200
# Found rating: 8.8
# Accessing URL: https://www.imdb.com/title/tt0109831/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0110357/
# Response status code: 200
# Found rating: 8.5
# Accessing URL: https://www.imdb.com/title/tt0110475/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0110478/
# Response status code: 200
# Found rating: 7.0
# Accessing URL: https://www.imdb.com/title/tt0110622/
# Response status code: 200
# Found rating: 6.5
# Accessing URL: https://www.imdb.com/title/tt0111257/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0111503/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0106220/
# Response status code: 200
# Found rating: 6.8
# Accessing URL: https://www.imdb.com/title/tt0109254/
# Response status code: 200
# Found rating: 5.5
# Accessing URL: https://www.imdb.com/title/tt0109439/
# Response status code: 200
# Found rating: 5.6
# Accessing URL: https://www.imdb.com/title/tt0106582/
# Response status code: 200
# Found rating: 6.5
# Accessing URL: https://www.imdb.com/title/tt0106598/
# Response status code: 200
# Found rating: 5.4
# Accessing URL: https://www.imdb.com/title/tt0106673/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0106697/
# Response status code: 200
# Found rating: 6.7
# Accessing URL: https://www.imdb.com/title/tt0106918/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0106977/
# Response status code: 200
# Found rating: 7.8
# Accessing URL: https://www.imdb.com/title/tt0107144/
# Response status code: 200
# Found rating: 6.6
# Accessing URL: https://www.imdb.com/title/tt0107206/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0107290/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0107362/
# Response status code: 200
# Found rating: 6.5
# Accessing URL: https://www.imdb.com/title/tt0107614/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0107818/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0107822/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0107977/
# Response status code: 200
# Found rating: 6.7
# Accessing URL: https://www.imdb.com/title/tt0108052/
# Response status code: 200
# Found rating: 9.0
# Accessing URL: https://www.imdb.com/title/tt0108160/
# Response status code: 200
# Found rating: 6.8
# Accessing URL: https://www.imdb.com/title/tt0083658/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0107688/
# Response status code: 200
# Found rating: 7.9
# Accessing URL: https://www.imdb.com/title/tt0108333/
# Response status code: 200
# Found rating: 6.4
# Accessing URL: https://www.imdb.com/title/tt0108358/
# Response status code: 200
# Found rating: 7.8
# Accessing URL: https://www.imdb.com/title/tt0108399/
# Response status code: 200
# Found rating: 7.9
# Accessing URL: https://www.imdb.com/title/tt0099785/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0099653/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0103639/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0103064/
# Response status code: 200
# Found rating: 8.6
# Accessing URL: https://www.imdb.com/title/tt0099348/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0096895/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0102926/
# Response status code: 200
# Found rating: 8.6
# Accessing URL: https://www.imdb.com/title/tt0029583/
# Response status code: 200
# Found rating: 7.6
# Accessing URL: https://www.imdb.com/title/tt0101414/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0032910/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0100405/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0116282/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0117060/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0116136/
# Response status code: 200
# Found rating: 6.4
# Accessing URL: https://www.imdb.com/title/tt0117705/
# Response status code: 200
# Found rating: 6.5
# Accessing URL: https://www.imdb.com/title/tt0117979/
# Response status code: 200
# Found rating: 6.3
# Accessing URL: https://www.imdb.com/title/tt0117500/
# Response status code: 200
# Found rating: 7.4
# Accessing URL: https://www.imdb.com/title/tt0117998/
# Response status code: 200
# Found rating: 6.5
# Accessing URL: https://www.imdb.com/title/tt0057012/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0117951/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0116629/
# Response status code: 200
# Found rating: 7.0
# Accessing URL: https://www.imdb.com/title/tt0115798/
# Response status code: 200
# Found rating: 6.1
# Accessing URL: https://www.imdb.com/title/tt0116213/
# Response status code: 200
# Found rating: 6.2
# Accessing URL: https://www.imdb.com/title/tt0117218/
# Response status code: 200
# Found rating: 5.7
# Accessing URL: https://www.imdb.com/title/tt0068646/
# Response status code: 200
# Found rating: 9.2
# Accessing URL: https://www.imdb.com/title/tt0052357/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0047396/
# Response status code: 200
# Found rating: 8.5
# Accessing URL: https://www.imdb.com/title/tt0053125/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0034583/
# Response status code: 200
# Found rating: 8.5
# Accessing URL: https://www.imdb.com/title/tt0032138/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0033467/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0062622/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0038650/
# Response status code: 200
# Found rating: 8.6
# Accessing URL: https://www.imdb.com/title/tt0058331/
# Response status code: 200
# Found rating: 7.8
# Accessing URL: https://www.imdb.com/title/tt0059742/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0095016/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0067992/
# Response status code: 200
# Found rating: 7.8
# Accessing URL: https://www.imdb.com/title/tt0095159/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0079470/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0105236/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0091763/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0083866/
# Response status code: 200
# Found rating: 7.9
# Accessing URL: https://www.imdb.com/title/tt0092099/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0096754/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0071853/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0108598/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0073486/
# Response status code: 200
# Found rating: 8.7
# Accessing URL: https://www.imdb.com/title/tt0080684/
# Response status code: 200
# Found rating: 8.7
# Accessing URL: https://www.imdb.com/title/tt0093779/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0082971/
# Response status code: 200
# Found rating: 8.4
# Accessing URL: https://www.imdb.com/title/tt0088846/
# Response status code: 200
# Found rating: 7.8
# Accessing URL: https://www.imdb.com/title/tt0090605/
# Response status code: 200
# Found rating: 8.4
# Accessing URL: https://www.imdb.com/title/tt0060196/
# Response status code: 200
# Found rating: 8.8
# Accessing URL: https://www.imdb.com/title/tt0050083/
# Response status code: 200
# Found rating: 9.0
# Accessing URL: https://www.imdb.com/title/tt0066921/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0056592/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0078788/
# Response status code: 200
# Found rating: 8.4
# Accessing URL: https://www.imdb.com/title/tt0086190/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0099685/
# Response status code: 200
# Found rating: 8.7
# Accessing URL: https://www.imdb.com/title/tt0078748/
# Response status code: 200
# Found rating: 8.5
# Accessing URL: https://www.imdb.com/title/tt0106308/
# Response status code: 200
# Found rating: 7.4
# Accessing URL: https://www.imdb.com/title/tt0054215/
# Response status code: 200
# Found rating: 8.5
# Accessing URL: https://www.imdb.com/title/tt0080455/
# Response status code: 200
# Found rating: 7.9
# Accessing URL: https://www.imdb.com/title/tt0071562/
# Response status code: 200
# Found rating: 9.0
# Accessing URL: https://www.imdb.com/title/tt0093058/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0086879/
# Response status code: 200
# Found rating: 8.4
# Accessing URL: https://www.imdb.com/title/tt0075686/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0070735/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0088247/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0097165/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0061722/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0071315/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0081505/
# Response status code: 200
# Found rating: 8.4
# Accessing URL: https://www.imdb.com/title/tt0092005/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0107048/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0088763/
# Response status code: 200
# Found rating: 8.5
# Accessing URL: https://www.imdb.com/title/tt0061512/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0072431/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0032455/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0088258/
# Response status code: 200
# Found rating: 7.9
# Accessing URL: https://www.imdb.com/title/tt0097576/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0097351/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0064115/
# Response status code: 200
# Found rating: 8.0
# Accessing URL: https://www.imdb.com/title/tt0098635/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0117731/
# Response status code: 200
# Found rating: 7.6
# Accessing URL: https://www.imdb.com/title/tt0099423/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0084726/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0103776/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0077631/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0073195/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0116996/
# Response status code: 200
# Found rating: 6.4
# Accessing URL: https://www.imdb.com/title/tt0116695/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0093822/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0117571/
# Response status code: 200
# Found rating: 7.4
# Accessing URL: https://www.imdb.com/title/tt0119008/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0119528/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0119229/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0118655/
# Response status code: 200
# Found rating: 7.0
# Accessing URL: https://www.imdb.com/title/tt0119116/
# Response status code: 200
# Found rating: 7.6
# Accessing URL: https://www.imdb.com/title/tt0119567/
# Response status code: 200
# Found rating: 6.6
# Accessing URL: https://www.imdb.com/title/tt0118880/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0119094/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0119654/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0118884/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0118571/
# Response status code: 200
# Found rating: 6.5
# Accessing URL: https://www.imdb.com/title/tt0099810/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0119488/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0119174/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0118842/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0119164/
# Response status code: 200
# Found rating: 7.2
# Accessing URL: https://www.imdb.com/title/tt0118971/
# Response status code: 200
# Found rating: 7.5
# Accessing URL: https://www.imdb.com/title/tt0119177/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0120201/
# Response status code: 200
# Found rating: 7.3
# Accessing URL: https://www.imdb.com/title/tt0120382/
# Response status code: 200
# Found rating: 8.2
# Accessing URL: https://www.imdb.com/title/tt0119217/
# Response status code: 200
# Found rating: 8.3
# Accessing URL: https://www.imdb.com/title/tt0120338/
# Response status code: 200
# Found rating: 7.9
# Accessing URL: https://www.imdb.com/title/tt0118715/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0120888/
# Response status code: 200
# Found rating: 6.9
# Accessing URL: https://www.imdb.com/title/tt0119822/
# Response status code: 200
# Found rating: 7.7
# Accessing URL: https://www.imdb.com/title/tt0120591/
# Response status code: 200
# Found rating: 6.7
# Accessing URL: https://www.imdb.com/title/tt0129387/
# Response status code: 200
# Found rating: 7.1
# Accessing URL: https://www.imdb.com/title/tt0075148/
# Response status code: 200
# Found rating: 8.1
# Accessing URL: https://www.imdb.com/title/tt0095953/

# %%
import pandas as pd

ratings_df = pd.read_csv('movie_imdb_ratings.csv')

merged_df = pd.merge(filtered_df, links_df, on='movieId')

merged_ratings_df = pd.merge(merged_df, ratings_df, left_on='title', right_on='Title')

highest_rated_movie = merged_ratings_df.loc[merged_ratings_df['IMDb Rating'].astype(float).idxmax()]

highest_rated_movieId = highest_rated_movie['movieId']
highest_rated_movie_name = highest_rated_movie['title']

print(f"The Sci-Fi movie with the highest IMDb rating is '{highest_rated_movie_name}' and movieId: {highest_rated_movieId}")

# %%
import pandas as pd

sci_fi_movies = merged_ratings_df[merged_ratings_df['genres'].str.contains('Sci-Fi')]

highest_rated_sci_fi_movie = sci_fi_movies.loc[sci_fi_movies['IMDb Rating'].astype(float).idxmax()]

highest_rated_sci_fi_movieId = highest_rated_sci_fi_movie['movieId']
highest_rated_sci_fi_movie_name = highest_rated_sci_fi_movie['title']

print(f"The Sci-Fi movie with the highest IMDb rating is '{highest_rated_sci_fi_movie_name}' with movieId: {highest_rated_sci_fi_movieId}")
